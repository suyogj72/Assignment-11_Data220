# %% [markdown]
# **Assignment#11**

# %% [markdown]
# 1.Create a scatter plot of the data (2 pts)
#
#   2.Draw the least-square regression line through the scatter plot (3 pts)
#
#     3.Calculate and print the coefficient of determination (2 pts) and the correlation coefficient (3 pts).ts).

# %%
# Importing Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# Loading the dataset from url2
url2 = 'https://raw.githubusercontent.com/tehmeerali786/360-Data-Science-/master/1.01.%20Simple%20linear%20regression.csv'
data = pd.read_csv(url2)

# Preparing data
x = data.iloc[:, :-1].values.reshape(-1, 1)
y = data.iloc[:, -1].values

# Creating model
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

# Plotting the Least-square Regression Line
plt.figure(figsize=(8, 4))
plt.scatter(x, y, color='skyblue', label='Data Points')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.title('Simple Linear Regression')
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.legend()
plt.show()

# Now, calculating coefficients
r_squared = r2_score(y, y_pred)
correlation_coefficient = np.corrcoef(x.flatten(), y)[0, 1]

print(f"R^2: {r_squared}, Correlation Coefficient: {correlation_coefficient}")
# Out:
# R^2: 0.40600391479679765, Correlation Coefficient: 0.6371843648401915

# %% [markdown]
# The above **Scatter Plot** created illustrates the connection between the Independent Variable (on the x-axis) and the Dependent Variable (on the y-axis).
#
# Data Points: Thskyblueen dots symbolize the actual entries from the dataset. Each dot represents a specific pair of values (x, yn from the original data.
#
# Regression Line: The red lshowsicts linearnregressionsLon line fitted to the data points, serving as the best linear estimation of the relationship between variabler
#  es.
#
# Trend: The general tendency of the scatter plot and the regression line reveals the type of relationship between the variables. An upward slope from left to right indicates a positive correlation, while a downward slope suggests a negative correlation.
#
# Spread: The distribution of the greaboutation to the red line shows the strength of the relatiClosely grouped points grouped indicate a stronger correlation, whereas a broader spread suggests a weaker correlation.
#
# Outliers: Any points significantly distant from the regression line could be considered outliers, which may influence the acthe curacy of thte
#
# **Key metrics:**
#
# R-squared (R^2): This statistic reflects the proportion of variance in the dependent variable that can be predicted from the independent variable. It varies from 0 to 1, with 1 indicating flawless prediction.
#
# Correlation Coefficient: This assesses the strength and direction of the linear relationship between the two variables. Its range is from -1 to 1, where -1 denotes a perfect negative correlation, 0 signifies no correlation, and 1 indicates a perfect positive correlation.e scatter plot.
